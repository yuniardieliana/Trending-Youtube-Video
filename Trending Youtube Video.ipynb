# %%
import pandas as pd

# %%
read = pd.read_csv('CAvideos.csv')

# %%
read
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...                                                  ...               ...
# ...

# %%
df = read[['video_id','trending_date','title','category_id','views','likes','dislikes']]

# %%
df
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title  category_id  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé           10
# 1                          PLUSH - Bad Unboxing Fan Mail           23
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...           23
# 3                               I Dare You: GOING BALD!?           24
# 4            Ed Sheeran - Perfect (Official Music Video)           10
# ...                                                  ...          ...
# ...

# %%
df1 = read[['title','views']]

# %%
df1
# Out:
#                                                    title     views
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé  17158579
# 1                          PLUSH - Bad Unboxing Fan Mail   1014651
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...   3191434
# 3                               I Dare You: GOING BALD!?   2095828
# 4            Ed Sheeran - Perfect (Official Music Video)  33523622
# ...                                                  ...       ...
# 40876                       HOW2: How to Solve a Mystery     80685
# 40877                   Eli Lik Lik Episode 13 Partie 01    103339
# 40878  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...    773347
# 40879                   Trump Advisor Grovels To Trudeau    115225
# 40880                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班    107392
#
# [40881 rows x 2 columns]

# %%
df1.sort_values(by=['views'], inplace=True, ascending = False)

# %%
print(df1)
# Out:
#                                                    title      views
# 5900   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  137843120
# 5623   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  125431369
# 5398   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  113876217
# 5197   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  100911567
# 34361  Childish Gambino - This Is America (Official V...   98938809
# ...                                                  ...        ...
# 579                        018 Algebra Lineal 18-10-2011       1141
# 20505  Simon Olivier Fecteau créateur des derniers By...       1107
# 18076  Raptors Post-Game: DeMar DeRozan - February 13...       1023
# 18045  Canadian Olympian receives death threats from ...       1000
# 34625          ''Gala Artis 2018'' Le numéro d'ouverture        733
#
# [40881 rows x 2 columns]

# %%
hasil = pd.DataFrame(df1)

# %%
hasil.head(10)
# Out:
#                                                    title      views
# 5900   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  137843120
# 5623   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  125431369
# 5398   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  113876217
# 5197   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  100911567
# 34361  Childish Gambino - This Is America (Official V...   98938809
# 4699   Marvel Studios' Avengers: Infinity War Officia...   89930713
# 4451   Marvel Studios' Avengers: Infinity War Officia...   87450245
# 34131  Childish Gambino - This Is America (Official V...   85092067
# 4202   Marvel Studios' Avengers: Infinity War Officia...   84281319
# 36453                BTS (방탄소년단) 'FAKE LOVE' Official MV   80738011

# %%
df2 = read[['title','likes']]

# %%
df2
# Out:
#                                                    title    likes
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé   787425
# 1                          PLUSH - Bad Unboxing Fan Mail   127794
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...   146035
# 3                               I Dare You: GOING BALD!?   132239
# 4            Ed Sheeran - Perfect (Official Music Video)  1634130
# ...                                                  ...      ...
# 40876                       HOW2: How to Solve a Mystery     1701
# 40877                   Eli Lik Lik Episode 13 Partie 01      460
# 40878  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...    25900
# 40879                   Trump Advisor Grovels To Trudeau     2115
# 40880                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班      300
#
# [40881 rows x 2 columns]

# %%
df2.sort_values(by=['likes'], inplace=True, ascending=False)

# %%
print(df2)
# Out:
#                                                    title    likes
# 36453                BTS (방탄소년단) 'FAKE LOVE' Official MV  5053338
# 36153                BTS (방탄소년단) 'FAKE LOVE' Official MV  4924056
# 35900                BTS (방탄소년단) 'FAKE LOVE' Official MV  4750254
# 35685                BTS (방탄소년단) 'FAKE LOVE' Official MV  4470888
# 35515                BTS (방탄소년단) 'FAKE LOVE' Official MV  3880074
# ...                                                  ...      ...
# 8494   Playful Meghan Markle  Pokes Out Her TONGUE In...        0
# 4960            2017.12.06新聞深喉嚨　 勞基法修出兩個太陽矛盾？賴執意加碼　蔡踩煞車？        0
# 13704  مرحلة المواجهة: يمان قصار، تيم الحلبي وزياد أمونة        0
# 22695  Big Brother Canada 6 | Thursday Eviction Recap...        0
# 7482   NEW Shaun The Sheep Full Episodes - Best Funny...        0
#
# [40881 rows x 2 columns]

# %%
hasil = pd.DataFrame(df2)

# %%
hasil.head(10)
# Out:
#                                                    title    likes
# 36453                BTS (방탄소년단) 'FAKE LOVE' Official MV  5053338
# 36153                BTS (방탄소년단) 'FAKE LOVE' Official MV  4924056
# 35900                BTS (방탄소년단) 'FAKE LOVE' Official MV  4750254
# 35685                BTS (방탄소년단) 'FAKE LOVE' Official MV  4470888
# 35515                BTS (방탄소년단) 'FAKE LOVE' Official MV  3880074
# 34361  Childish Gambino - This Is America (Official V...  3037318
# 5900   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  3014479
# 5623   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  2912715
# 5398   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  2811217
# 34131  Childish Gambino - This Is America (Official V...  2735961

# %%
df3 = read[['title','dislikes']]

# %%
df3
# Out:
#                                                    title  dislikes
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé     43420
# 1                          PLUSH - Bad Unboxing Fan Mail      1688
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      5339
# 3                               I Dare You: GOING BALD!?      1989
# 4            Ed Sheeran - Perfect (Official Music Video)     21082
# ...                                                  ...       ...
# 40876                       HOW2: How to Solve a Mystery        99
# 40877                   Eli Lik Lik Episode 13 Partie 01        66
# 40878  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...       224
# 40879                   Trump Advisor Grovels To Trudeau       182
# 40880                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班        62
#
# [40881 rows x 2 columns]

# %%
df3.sort_values(by=['dislikes'], inplace=True, ascending=False)

# %%
print (df3)
# Out:
#                                                    title  dislikes
# 5900   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   1602383
# 5623   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   1545018
# 5398   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   1470387
# 5197   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   1353655
# 4996   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   1127811
# ...                                                  ...       ...
# 35827  Grey's Anatomy 14x24 Matthew Proposes to April...         0
# 23915  The Flash 4x16 Ending Scene Season 4 Episode 1...         0
# 1278    GET READY WITH US  Feat: JACLYN HILL & MANNY MUA         0
# 31169                              圆桌派S3 第21集 细节 魔鬼藏在细节里         0
# 20093  Raptors Shootaround: O.G. Anunoby - February 2...         0
#
# [40881 rows x 2 columns]

# %%
hasil = pd.DataFrame(df3)

# %%
hasil.head(10)
# Out:
#                                                    title  dislikes
# 5900   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   1602383
# 5623   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   1545018
# 5398   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   1470387
# 5197   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   1353655
# 4996   YouTube Rewind: The Shape of 2017 | #YouTubeRe...   1127811
# 4795   YouTube Rewind: The Shape of 2017 | #YouTubeRe...    884963
# 2898   Jake Paul - It's Everyday Bro (Remix) [feat. G...    504340
# 4597   YouTube Rewind: The Shape of 2017 | #YouTubeRe...    483943
# 2627   Jake Paul - It's Everyday Bro (Remix) [feat. G...    480359
# 14852                         Suicide: Be Here Tomorrow.    461660
